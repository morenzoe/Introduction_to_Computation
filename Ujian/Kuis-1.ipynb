# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Nama     : Eraraya Morenzo Muten
#NIM      : 16520002
#Tanggal  : 02 November 2020
#Soal 1 Kuis 1

#Program Gaya Gravitasi
#program ini akan menghitung gaya gravitasi dari dua buah benda

#KAMUS
# m1 = float
# m2 = float
# r = float

#ALGORITMA
m1 = float(input("masukkan m1: "))        #menerima input m1, asumsi m1>0
m2 = float(input("masukkan m2: "))        #menerima input m2, asumsi m2>0
r = float(input("masukkan r: "))          #menerima input r, asumsi r>0

print(((6.674)*10**(-11)*m1*m2)/r**2)     #mencetak hasil perhitungan gaya gravitasi
# Out:
# masukkan m1: 19
# masukkan m2: 21
# masukkan r: 13
# 1.5756958579881656e-10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Nama     : Eraraya Morenzo Muten
#NIM      : 16520002
#Tanggal  : 02 November 2020
#Soal 2 Kuis 1

#Program Segitiga
#program ini akan memeriksa apakah tiga bilangan sisi dapat membentuk segitiga

#KAMUS
# a = float
# b = float
# c = float

#ALGORITMA
a = float(input("masukkan a: "))                                                #menerima input panjang sisi
b = float(input("masukkan b: "))
c = float(input("masukkan c: "))

if a>0.0 and b>0.0 and c>0.0:                                                   #memeriksa tanda ketiga bilangan
  if a+b>c and a+c>b and b+c>a:                                                 #memeriksa penjumlahan kombinasi
    print("Ketiga bilangan dapat membentuk segitiga")                           #mencetak hasil pemeriksaan
  else:
    print("Ketiga bilangan tidak dapat membentuk segitiga")                     #mencetak hasil pemeriksaan
else:
  print("Ketiga bilangan tidak dapat membentuk segitiga")                       #mencetak hasil pemeriksaan
# Out:
# masukkan a: -3
# masukkan b: 0
# masukkan c: 5
# Ketiga bilangan tidak dapat membentuk segitiga

# %% [markdown]
# ![Screenshot_2020-11-02 Kuis-1 Minggu 07.png](data:image/png;base64,...)

# %%
#Nama     : Eraraya Morenzo Muten
#NIM      : 16520002
#Tanggal  : 02 November 2020
#Soal 3 Kuis 1

#Program Kedalaman Sungai
#program ini akan menghitung rata-rata dari beberapa data kedalaman sungai

#KAMUS
# N = int
# i = int
# h = float
# k = boolean

#ALGORITMA
k = False                                                                       #inisialisasi kondisi pengulangan
while k == False:                                                               #pengulangan input N
  N = float(input("Masukkan banyaknya data = "))                                 #asumsi N adalah bilangan bulat
  if N>0:                                                                       #memastikan N bilangan positif
    k = True                                                                    #terminasi pengulangan
  else:
    print("Masukan salah. Ulangi.")                                             

h = 0                                                                           #inisialisasi perhitungan jumlah
print("Data kedalaman sungai = ")
for i in range(int(N)):                                                         #pengulangan sebanyak N kali
  h = h + float(input())                                                     
print("Rata-rata kedalaman sungai = " + str(round(h/N, 2)))                     #mencetak hasil (2 angka desimal)
# Out:
# Masukkan banyaknya data: 3
# Data kedalaman sungai =
# 500
# 510
# 420
# Rata-rata kedalaman sungai = 476.67
