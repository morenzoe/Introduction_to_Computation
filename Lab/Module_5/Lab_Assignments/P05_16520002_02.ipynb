# %%
# NIM/Nama	  	: 16520002/Eraraya Morenzo Muten
# Tanggal	  	  : 16 Desember 2020
# Shift/Kelas	  : 3.1/A

# Problem 2

# %% [markdown]
# Import Library

# %%
import pandas as pd

# %% [markdown]
# Membaca File CSV

# %%
# membaca file csv pada directory yang sama dengan notebook ini sebagai DataFrame Pandas
df = pd.read_csv('crypto.csv')

# %% [markdown]
# Nomor 1

# %%
# menampilkan data untuk koin USDT
df.loc[df['name']=='USDT']
# Out:
#       name        date  ranknow  ...        market  close_ratio  spread
# 5197  USDT  2015-02-25        8  ...  3.047130e+05       0.0000    0.01
# 5198  USDT  2015-02-26        8  ...  3.033640e+05       1.0000    0.02
# 5199  USDT  2015-03-02        8  ...  1.525960e+05       0.9649    0.04
# 5200  USDT  2015-03-03        8  ...  1.525270e+05       1.0000    0.00
# 5201  USDT  2015-03-06        8  ...  2.516000e+05       0.0000    0.00
# ...    ...         ...      ...  ...           ...          ...     ...
# 6561  USDT  2018-11-25        8  ...  1.821092e+09       0.6722    0.03
# 6562  USDT  2018-11-26        8  ...  1.814175e+09       0.3782    0.02
# 6563  USDT  2018-11-27        8  ...  1.827202e+09       0.7074    0.03
# 6564  USDT  2018-11-28        8  ...  1.853864e+09       0.6196    0.03
# 6565  USDT  2018-11-29        8  ...  1.851553e+09       0.2965    0.02
#
# [1369 rows x 11 columns]

# %% [markdown]
# Nomor 2

# %%
# menampilkan data yang ada pada tanggal 4 Juli 2016
# pada data ini, tanggal 4 Juli 2016 ditulis sebagai 2016-07-04
df.loc[df['date']=='2016-07-04']

#  	    name 	      date 	ranknow 	      open 	      high 	       low 	     close 	    volume 	      market 	close_ratio 	spread
# 1163 	 BTC 	2016-07-04 	      1 	658.800000 	683.660000 	650.510000 	683.660000 	92008400.0 	1.075623e+10 	     1.0000 	 33.15
# 3107 	 XRP 	2016-07-04 	      2 	  0.006621 	  0.008447 	  0.006599 	  0.007028 	  875970.0 	2.484005e+08 	     0.2321 	  0.00
# 4318 	 ETH 	2016-07-04 	      3 	 11.700000 	 11.880000 	 11.390000 	 11.470000 	12943500.0 	9.368404e+08 	     0.1633 	  0.49
# 5687 	USDT 	2016-07-04 	      8 	  1.000000 	  1.000000 	  1.000000 	  1.000000 	 1703670.0 	5.951591e+06 	     0.0000 	  0.00
# 7340 	 XMR 	2016-07-04 	     11 	  1.700000 	  1.800000 	  1.660000 	  1.710000 	  151474.0 	2.106825e+07 	     0.3571 	  0.14
# Out:
#       name        date  ranknow  ...        market  close_ratio  spread
# 1163   BTC  2016-07-04        1  ...  1.075623e+10       1.0000   33.15
# 3107   XRP  2016-07-04        2  ...  2.484005e+08       0.2321    0.00
# 4318   ETH  2016-07-04        3  ...  9.368404e+08       0.1633    0.49
# 5687  USDT  2016-07-04        8  ...  5.951591e+06       0.0000    0.00
# 7340   XMR  2016-07-04       11  ...  2.106825e+07       0.3571    0.14
#
# [5 rows x 11 columns]

# %% [markdown]
# Nomor 3

# %%
# mengurutkan DataFrame berdasarkan nilai kolom high dari yang tertinggi ke terrendah
df_high = df.sort_values(by = ['high'], ascending = False)
# menampilkan 5 data dengan nilai high tertinggi
df_high[:10]

#  	   name 	      date 	ranknow 	   open 	   high 	   low 	    close 	      volume 	      market 	close_ratio 	spread
# 1694 	BTC 	2017-12-17 	      1 	19475.8 	20089.0 	18974.1 	19140.8 	1.331460e+10 	3.205766e+11 	     0.1495 	1114.9
# 1693 	BTC 	2017-12-16 	      1 	17760.3 	19716.7 	17515.3 	19497.4 	1.274060e+10 	3.265025e+11 	     0.9004 	2201.4
# 1695 	BTC 	2017-12-18 	      1 	19106.4 	19371.0 	18355.9 	19114.2 	1.483950e+10 	3.201743e+11 	     0.7470 	1015.1
# 1696 	BTC 	2017-12-19 	      1 	19118.3 	19177.8 	17275.4 	17776.7 	1.689450e+10 	2.978011e+11 	     0.2635 	1902.4
# 1685 	BTC 	2017-12-08 	      1 	17802.9 	18353.4 	14336.9 	16569.4 	2.113600e+10 	2.771858e+11 	     0.5558 	4016.5
# 1692 	BTC 	2017-12-15 	      1 	16601.3 	18154.1 	16601.3 	17706.9 	1.431000e+10 	2.964821e+11 	     0.7120 	1552.8
# 1697 	BTC 	2017-12-20 	      1 	17760.3 	17934.7 	16077.7 	16624.6 	2.214970e+10 	2.785290e+11 	     0.2945 	1857.0
# 1684 	BTC 	2017-12-07 	      1 	14266.1 	17899.7 	14057.3 	17899.7 	1.795070e+10 	2.994054e+11 	     1.0000 	3842.4
# 1689 	BTC 	2017-12-12 	      1 	16919.8 	17781.8 	16571.6 	17415.4 	1.460380e+10 	2.914839e+11 	     0.6972 	1210.2
# 1714 	BTC 	2018-01-06 	      1 	17462.1 	17712.4 	16764.6 	17527.0 	1.831460e+10 	2.942174e+11 	     0.8044 	 947.8
# Out:
#      name        date  ranknow  ...        market  close_ratio  spread
# 1694  BTC  2017-12-17        1  ...  3.205766e+11       0.1495  1114.9
# 1693  BTC  2017-12-16        1  ...  3.265025e+11       0.9004  2201.4
# 1695  BTC  2017-12-18        1  ...  3.201743e+11       0.7470  1015.1
# 1696  BTC  2017-12-19        1  ...  2.978011e+11       0.2635  1902.4
# 1685  BTC  2017-12-08        1  ...  2.771858e+11       0.5558  4016.5
# 1692  BTC  2017-12-15        1  ...  2.964821e+11       0.7120  1552.8
# 1697  BTC  2017-12-20        1  ...  2.785290e+11       0.2945  1857.0
# 1684  BTC  2017-12-07        1  ...  2.994054e+11       1.0000  3842.4
# 1689  BTC  2017-12-12        1  ...  2.914839e+11       0.6972  1210.2
# 1714  BTC  2018-01-06        1  ...  2.942174e+11       0.8044   947.8
#
# [10 rows x 11 columns]

# %% [markdown]
# Nomor 4

# %%
# menampilkan nilai close tertinggi
print("Nilai close tertinggi adalah", df['close'].max())

# Nilai close tertinggi adalah 19497.4
# Out:
# Nilai close tertinggi adalah 19497.4

# %% [markdown]
# Nomor 5

# %%
# pada data ini, nilai kolom high tertinggi dari cryptocurrency ETH hanya terdapat pada 1 tanggal
# menyimpan indeks baris nilai high tertinggi dari cryptocurrency ETH
idx = df.loc[df['name']=='ETH']['high'].idxmax()
# menampilkan tanggal dari data pada baris tersebut
print("Nilai high tertinggi ETH terjadi pada tanggal", df['date'][idx])

# Nilai high tertinggi ETH terjadi pada tanggal 2018-01-13
# pada data ini, 2018-01-13 dapat dibaca sebagai 13 Januari 2018
# Out:
# Nilai high tertinggi ETH terjadi pada tanggal 2018-01-13
