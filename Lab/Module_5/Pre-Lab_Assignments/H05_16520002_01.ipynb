# %%
# NIM/Nama	  	: 16520002/Eraraya Morenzo Muten
# Tanggal	  	  : 13 Desember 2020
# Shift/Kelas	  : 3.1/A

# Problem 1

# %% [markdown]
# Import Library

# %%
import pandas as pd

# %% [markdown]
# Membaca File CSV

# %%
# membaca file csv pada directory yang sama dengan notebook ini sebagai DataFrame Pandas
df = pd.read_csv('nilai_uas.csv')

# %% [markdown]
# Nomor 1

# %%
# menampilkan banyak data
print("Banyak data pada data nilai UAS mahasiswa ini adalah", len(df))
# Banyak data pada data nilai UAS mahasiswa ini adalah 3562
# Out:
# Banyak data pada data nilai UAS mahasiswa ini adalah 3562

# %% [markdown]
# Nomor 2

# %%
# menampilkan 10 data pertama
print(df[:10])
#  	                 nama fakultas 	nilai_kal 	nilai_fis 	nilai_kim
# 0 	       Raihan Daris 	    SF 	    60.27 	    65.59 	    51.70
# 1 	         Galuh Wina 	  STEI 	    52.99 	    55.25 	    66.31
# 2 	       Johannes Sun 	 FMIPA 	    51.20 	    51.30 	    84.70
# 3 	Abdurrahman WIlliam 	  FTSL 	    31.17 	    36.88 	    50.25
# 4 	       Rayhan Faris 	  STEI 	    55.55 	    57.61 	    67.46
# 5 	Margareth Widyatama 	  FTTM 	    42.78 	    50.23 	    71.17
# 6 	    Christofer Jaza 	  FTSL 	    31.64 	    38.03 	    34.99
# 7 	       Wafika Nadia 	    SF 	    60.96 	    57.54 	    76.03
# 8 	Elizabeth Parikesit 	  STEI 	    54.35 	    55.30 	    59.15
# 9 	       Halida Aqila    SITHR 	    63.71 	    67.23 	    63.76
# Out:
#                   nama fakultas  nilai_kal  nilai_fis  nilai_kim
# 0         Raihan Daris       SF      60.27      65.59      51.70
# 1           Galuh Wina     STEI      52.99      55.25      66.31
# 2         Johannes Sun    FMIPA      51.20      51.30      84.70
# 3  Abdurrahman WIlliam     FTSL      31.17      36.88      50.25
# 4         Rayhan Faris     STEI      55.55      57.61      67.46
# 5  Margareth Widyatama     FTTM      42.78      50.23      71.17
# 6      Christofer Jaza     FTSL      31.64      38.03      34.99
# 7         Wafika Nadia       SF      60.96      57.54      76.03
# 8  Elizabeth Parikesit     STEI      54.35      55.30      59.15
# 9         Halida Aqila    SITHR      63.71      67.23      63.76

# %% [markdown]
# Nomor 3

# %%
# menampilkan data ke-50 sampai ke-60
print(df[50-1:60])
#                  nama fakultas  nilai_kal  nilai_fis  nilai_kim
# 49     Kenesha Monica     FTTM      41.63      39.58      61.25
# 50     Ulul Mochammad     FTTM      38.75      44.24      40.11
# 51      George Vrince     FITB      44.02      45.15      41.76
# 52       Fayza Eunike     STEI      55.28      59.47      49.29
# 53      Kevin Faustin    SAPPK      47.72      49.65      52.76
# 54      salah Siagian    SAPPK      47.14      51.26      46.77
# 55      Nabilah Satya       SF      61.26      63.96      57.19
# 56   Tharisa Ghiffari     FSRD      74.14      78.86      54.59
# 57     Setyawan Ahmad     FSRD      75.18      78.33      51.35
# 58  Kelvin Salsabiela     FTTM      39.69      40.92      51.15
# 59      Sitorus Aidil     FTMD      58.49      55.54      55.20
# Out:
#                  nama fakultas  nilai_kal  nilai_fis  nilai_kim
# 49     Kenesha Monica     FTTM      41.63      39.58      61.25
# 50     Ulul Mochammad     FTTM      38.75      44.24      40.11
# 51      George Vrince     FITB      44.02      45.15      41.76
# 52       Fayza Eunike     STEI      55.28      59.47      49.29
# 53      Kevin Faustin    SAPPK      47.72      49.65      52.76
# 54      salah Siagian    SAPPK      47.14      51.26      46.77
# 55      Nabilah Satya       SF      61.26      63.96      57.19
# 56   Tharisa Ghiffari     FSRD      74.14      78.86      54.59
# 57     Setyawan Ahmad     FSRD      75.18      78.33      51.35
# 58  Kelvin Salsabiela     FTTM      39.69      40.92      51.15
# 59      Sitorus Aidil     FTMD      58.49      55.54      55.20

# %% [markdown]
# Nomor 4

# %%
# menampilkan banyaknya mahasiswa tiap fakultas
print("Banyaknya mahasiswa tiap fakultas adalah:")
print(df['fakultas'].value_counts().reset_index().rename(columns = {'index':'Fakultas', 'fakultas' : 'Jumlah'}))
# Banyaknya mahasiswa tiap fakultas adalah:
#    Fakultas  Jumlah
# 0      STEI     499
# 1      FTTM     454
# 2      FTSL     424
# 3     FMIPA     396
# 4      FTMD     352
# 5      FITB     283
# 6       SBM     261
# 7      FSRD     260
# 8     SAPPK     198
# 9     SITHR     179
# 10       SF     154
# 11    SITHS     102
# Out:
# Banyaknya mahasiswa tiap fakultas adalah:
#    Fakultas  Jumlah
# 0      STEI     499
# 1      FTTM     454
# 2      FTSL     424
# 3     FMIPA     396
# 4      FTMD     352
# 5      FITB     283
# 6       SBM     261
# 7      FSRD     260
# 8     SAPPK     198
# 9     SITHR     179
# 10       SF     154
# 11    SITHS     102

# %% [markdown]
# Nomor 5

# %%
# menampilkan nilai korelasi antara nilai kalkulus dan nilai fisika
print("Nilai korelasi antara nilai kalkulus dan nilai fisika", df['nilai_fis'].corr(df['nilai_kal']))
# Nilai korelasi antara nilai kalkulus dan nilai fisika 0.9605289823695181

# hasil mendekati 1, sehingga nilai kalkulus dan nilai fisika berkorelasi lurus
# Out:
# Nilai korelasi antara nilai kalkulus dan nilai fisika 0.9605289823695181
